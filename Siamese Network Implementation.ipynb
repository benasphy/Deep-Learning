# %% [markdown]
# <a href="https://colab.research.google.com/github/benasphy/Deep-Learning/blob/main/Siamese%20Network%20Implementation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import random
import cv2
import tensorflow as tf
from pathlib import Path
from tensorflow.keras import applications
from tensorflow.keras import layers
from tensorflow.keras import losses
from tensorflow.keras import optimizers
from tensorflow.keras import metrics
from tensorflow.keras import Model
from tensorflow.keras.applications import resnet
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split

# %%
# Function to generate image pairs
def generate_image_pairs(images, labels):
    # Generate index for each label
    unique_labels = np.unique(labels)
    label_wise_indices = dict()
    for label in unique_labels:
        label_wise_indices.setdefault(label,
                                      [index for index, curr_label in enumerate(labels) if
                                       label == curr_label])

    # Generate image pairs and labels
    pair_images = []
    pair_labels = []
    for index, image in enumerate(images):
        pos_indices = label_wise_indices.get(labels[index])
        pos_image = images[np.random.choice(pos_indices)]
        pair_images.append((image, pos_image))
        pair_labels.append(1)

        neg_indices = np.where(labels != labels[index])
        neg_image = images[np.random.choice(neg_indices[0])]
        pair_images.append((image, neg_image))
        pair_labels.append(0)

    return np.array(pair_images), np.array(pair_labels)

# %%
# Get the data directory paths
faces = '/content/olivetti_faces.npy'
faces_targets = '/content/olivetti_faces_target.npy'

# %%
# Load the images and labels
face_images = np.load(faces)
face_labels = np.load(faces_targets)

# %%
target_shape = face_images[0].shape

# %%
images_dataset, labels_dataset = generate_image_pairs(face_images, face_labels)
images_dataset, labels_dataset = shuffle(images_dataset, labels_dataset)

# %% [markdown]
# Visualize

# %%
def visualize(image_pairs, labels, n = 5, title = "Image Pair Examples"):
    """ Visualize a few pairs """

    def show(ax, image):
        ax.imshow(image)
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)

    fig = plt.figure(figsize=(9, 9))
    plt.title(title)
    axs = fig.subplots(n, 2)
    for i in range(n):
        show(axs[i, 0], image_pairs[i][0])
        show(axs[i, 1], image_pairs[i][1])

# %%
# Visualize Positive Images
n = 5
indices = np.where(labels_dataset == 1)[:n]
visualize(images_dataset[indices], labels_dataset[indices],
          title = "Positive Image Examples")

# %%
# Visualize Negative Images
n = 5
indices = np.where(labels_dataset == 0)[:n]
visualize(images_dataset[indices], labels_dataset[indices],
          title = "Negative Image Examples")

# %% [markdown]
# Network Architecture
#
# Embedding Layer

# %%
inputs = layers.Input((64, 64, 1))

x = layers.Conv2D(64, (10, 10), padding="same", activation="relu")(inputs)
x = layers.MaxPooling2D(pool_size=(2, 2))(x)
x = layers.Dropout(0.3)(x)

x = layers.Conv2D(128, (7, 7), padding="same", activation="relu")(x)
x = layers.MaxPooling2D(pool_size=(2, 2))(x)
x = layers.Dropout(0.3)(x)

x = layers.Conv2D(128, (4, 4), padding="same", activation="relu")(x)
x = layers.MaxPooling2D(pool_size=(2, 2))(x)
x = layers.Dropout(0.3)(x)

x = layers.Conv2D(256, (4, 4), padding="same", activation="relu")(x)
fcOutput = layers.Flatten()(x)
fcOutput = layers.Dense(4096, activation = "relu")(fcOutput)
outputs = layers.Dense(1024, activation = "sigmoid")(fcOutput)

embedding = Model(inputs, outputs, name = "Embedding")

# %% [markdown]
# Siamese Network

# %%
import tensorflow.keras.backend as K

# %%
# Define the Contrastive Loss
def contrastive_loss(y, preds, margin=1):
    y = tf.cast(y, preds.dtype)
    squaredPreds = K.square(preds)
    squaredMargin = K.square(K.maximum(margin - preds, 0))
    loss = K.mean(y * squaredPreds + (1 - y) * squaredMargin)

    return loss

# %%
# Distance Layer
class DistanceLayer(layers.Layer):
    """
    This layer is responsible for computing the distance
    between the embeddings
    """

    def __init__(self, **kwargs):
        super().__init__(**kwargs)

    def call(self, anchor, compare):
        sum_squared = K.sum(K.square(anchor - compare), axis=1, keepdims=True)
        return K.sqrt(K.maximum(sum_squared, K.epsilon()))

# %%
anchor_input = layers.Input(name="anchor", shape=target_shape + (1,))
compare_input = layers.Input(name="compare", shape=target_shape + (1,))

distances = DistanceLayer()(
    embedding(anchor_input),
    embedding(compare_input),
)

outputs = layers.Dense(1, activation = "sigmoid") (distances)

siamese_model = Model(
    inputs=[anchor_input, compare_input], outputs=outputs
)

# %% [markdown]
# Training

# %%
siamese_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])
history = siamese_model.fit([images_dataset[:, 0, :], images_dataset[:, 1, :]], labels_dataset,
                            epochs=60, validation_split = 0.2, batch_size = 64)
# Out:
# Epoch 1/60
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 144s 14s/step - accuracy: 0.4942 - loss: 0.6810 - val_accuracy: 0.5813 - val_loss: 0.6236
# Epoch 2/60
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 139s 14s/step - accuracy: 0.4597 - loss: 0.6494 - val_accuracy: 0.5813 - val_loss: 0.6060
# Epoch 3/60
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 141s 14s/step - accuracy: 0.5034 - loss: 0.6210 - val_accuracy: 0.6062 - val_loss: 0.6175
# Epoch 4/60
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 146s 14s/step - accuracy: 0.4923 - loss: 0.6274 - val_accuracy: 0.5938 - val_loss: 0.6116
# Epoch 5/60
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 137s 14s/step - accuracy: 0.4854 - loss: 0.6115 - val_accuracy: 0.6125 - val_loss: 0.6144
# Epoch 6/60
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 143s 14s/step - accuracy: 0.4665 - loss: 0.6373 - val_accuracy: 0.6125 - val_loss: 0.6007
# Epoch 7/60
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 142s 14s/step - accuracy: 0.5003 - loss: 0.6108 - val_accuracy: 0.5938 - val_loss: 0.6065
# Epoch 8/60
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 143s 14s/step - accuracy: 0.5303 - loss: 0.6046 - val_accuracy: 0.6375 - val_loss: 0.6132
# Epoch 9/60
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 137s 14s/step - accuracy: 0.5214 - loss: 0.6185 - val_accuracy: 0.6187 - val_loss: 0.5914
# Epoch 10/60
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 144s 14s/step - accuracy: 0.5398 - loss: 0.5897 - val_accuracy: 0.6500 - val_loss: 0.5708
# Epoch 11/60
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 139s 14s/step - accuracy: 0.5304 - loss: 0.5804 - val_accuracy: 0.6625 - val_loss: 0.5789
# Epoch 12/60
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 142s 14s/step - accuracy: 0.5418 - loss: 0.5791 - val_accuracy: 0.6500 - val_loss: 0.5885
# Epoch 13/60
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 144s 14s/step - accuracy: 0.5857 - loss: 0.5888 - val_accuracy: 0.6500 - val_loss: 0.5781
# Epoch 14/60
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 141s 14s/step - accuracy: 0.5663 - loss: 0.5552 - val_accuracy: 0.7625 - val_loss: 0.5691
# Epoch 15/60
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 140s 13s/step - accuracy: 0.5717 - loss: 0.5909 - val_accuracy: 0.6750 - val_loss: 0.5691
# Epoch 16/60
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 145s 14s/step - accuracy: 0.5736 - loss: 0.5766 - val_accuracy: 0.6625 - val_loss: 0.5540
# Epoch 17/60
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 138s 13s/step - accuracy: 0.5759 - loss: 0.5560 - val_accuracy: 0.6812 - val_loss: 0.5752
# Epoch 18/60
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 142s 13s/step - accuracy: 0.5915 - loss: 0.5588 - val_accuracy: 0.7000 - val_loss: 0.5581
# Epoch 19/60
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 135s 14s/step - accuracy: 0.5808 - loss: 0.5328 - val_accuracy: 0.6562 - val_loss: 0.5537
# Epoch 20/60
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 136s 14s/step - accuracy: 0.6412 - loss: 0.5564 - val_accuracy: 0.7063 - val_loss: 0.5613
# Epoch 21/60
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 140s 14s/step - accuracy: 0.6483 - loss: 0.5512 - val_accuracy: 0.7188 - val_loss: 0.5487
# Epoch 22/60
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 136s 14s/step - accuracy: 0.5879 - loss: 0.5540 - val_accuracy: 0.7250 - val_loss: 0.5385
# Epoch 23/60
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 141s 14s/step - accuracy: 0.6267 - loss: 0.5355 - val_accuracy: 0.6875 - val_loss: 0.5315
# Epoch 24/60
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 144s 14s/step - accuracy: 0.6330 - loss: 0.5261 - val_accuracy: 0.7375 - val_loss: 0.5286
# Epoch 25/60
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 141s 14s/step - accuracy: 0.6325 - loss: 0.5334 - val_accuracy: 0.7437 - val_loss: 0.5449
# Epoch 26/60
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 142s 14s/step - accuracy: 0.6560 - loss: 0.5308 - val_accuracy: 0.7250 - val_loss: 0.5501
# Epoch 27/60
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 144s 14s/step - accuracy: 0.6507 - loss: 0.5268 - val_accuracy: 0.7125 - val_loss: 0.5278
# Epoch 28/60
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 140s 14s/step - accuracy: 0.6556 - loss: 0.4903 - val_accuracy: 0.8062 - val_loss: 0.5467
# Epoch 29/60
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 141s 14s/step - accuracy: 0.7157 - loss: 0.5013 - val_accuracy: 0.7063 - val_loss: 0.5204
# Epoch 30/60
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 144s 14s/step - accuracy: 0.6884 - loss: 0.4982 - val_accuracy: 0.7437 - val_loss: 0.5219
# Epoch 31/60
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 139s 14s/step - accuracy: 0.7405 - loss: 0.4906 - val_accuracy: 0.7937 - val_loss: 0.5301
# Epoch 32/60
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 142s 13s/step - accuracy: 0.6999 - loss: 0.4769 - val_accuracy: 0.6812 - val_loss: 0.5238
# Epoch 33/60
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 143s 14s/step - accuracy: 0.7676 - loss: 0.4966 - val_accuracy: 0.7437 - val_loss: 0.5489
# Epoch 34/60
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 144s 14s/step - accuracy: 0.7381 - loss: 0.4893 - val_accuracy: 0.7437 - val_loss: 0.5102
# Epoch 35/60
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 141s 14s/step - accuracy: 0.7359 - loss: 0.4782 - val_accuracy: 0.7750 - val_loss: 0.4961
# Epoch 36/60
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 142s 14s/step - accuracy: 0.7640 - loss: 0.4845 - val_accuracy: 0.7500 - val_loss: 0.5066
# Epoch 37/60
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 143s 14s/step - accuracy: 0.7506 - loss: 0.4750 - val_accuracy: 0.7875 - val_loss: 0.5080
# Epoch 38/60
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 140s 14s/step - accuracy: 0.7655 - loss: 0.4372 - val_accuracy: 0.8000 - val_loss: 0.5257
# Epoch 39/60
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 137s 14s/step - accuracy: 0.7953 - loss: 0.4753 - val_accuracy: 0.7688 - val_loss: 0.5102
# Epoch 40/60
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 140s 14s/step - accuracy: 0.7781 - loss: 0.4645 - val_accuracy: 0.7688 - val_loss: 0.4668
# Epoch 41/60
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 144s 14s/step - accuracy: 0.8231 - loss: 0.4413 - val_accuracy: 0.7812 - val_loss: 0.4855
# Epoch 42/60
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 139s 14s/step - accuracy: 0.8207 - loss: 0.4303 - val_accuracy: 0.7875 - val_loss: 0.4867
# Epoch 43/60
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 143s 14s/step - accuracy: 0.7978 - loss: 0.4409 - val_accuracy: 0.7937 - val_loss: 0.5216
# Epoch 44/60
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 144s 14s/step - accuracy: 0.8136 - loss: 0.4244 - val_accuracy: 0.7812 - val_loss: 0.4791
# Epoch 45/60
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 135s 14s/step - accuracy: 0.8571 - loss: 0.4162 - val_accuracy: 0.8062 - val_loss: 0.4878
# Epoch 46/60
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 136s 14s/step - accuracy: 0.8278 - loss: 0.4229 - val_accuracy: 0.7750 - val_loss: 0.4627
# Epoch 47/60
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 141s 14s/step - accuracy: 0.8549 - loss: 0.4178 - val_accuracy: 0.8062 - val_loss: 0.4501
# Epoch 48/60
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 135s 14s/step - accuracy: 0.8330 - loss: 0.4530 - val_accuracy: 0.7688 - val_loss: 0.4558
# Epoch 49/60
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 132s 13s/step - accuracy: 0.8321 - loss: 0.4330 - val_accuracy: 0.7688 - val_loss: 0.5508
# Epoch 50/60
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 142s 13s/step - accuracy: 0.8097 - loss: 0.4437 - val_accuracy: 0.8062 - val_loss: 0.4805
# Epoch 51/60
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 144s 14s/step - accuracy: 0.8549 - loss: 0.4152 - val_accuracy: 0.8125 - val_loss: 0.4497
# Epoch 52/60
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 142s 14s/step - accuracy: 0.8754 - loss: 0.4091 - val_accuracy: 0.8313 - val_loss: 0.4361
# Epoch 53/60
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 135s 14s/step - accuracy: 0.8993 - loss: 0.3769 - val_accuracy: 0.8313 - val_loss: 0.4866
# Epoch 54/60
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 139s 13s/step - accuracy: 0.8732 - loss: 0.3981 - val_accuracy: 0.7875 - val_loss: 0.5145
# Epoch 55/60
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 145s 14s/step - accuracy: 0.8750 - loss: 0.3925 - val_accuracy: 0.8000 - val_loss: 0.4626
# Epoch 56/60
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 142s 14s/step - accuracy: 0.8552 - loss: 0.4028 - val_accuracy: 0.8438 - val_loss: 0.4410
# Epoch 57/60
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 142s 14s/step - accuracy: 0.8956 - loss: 0.3860 - val_accuracy: 0.8062 - val_loss: 0.4575
# Epoch 58/60
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 133s 13s/step - accuracy: 0.8880 - loss: 0.3786 - val_accuracy: 0.8125 - val_loss: 0.4588
# Epoch 59/60
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 142s 13s/step - accuracy: 0.9023 - loss: 0.3679 - val_accuracy: 0.8188 - val_loss: 0.4186
# Epoch 60/60
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 134s 13s/step - accuracy: 0.9152 - loss: 0.3818 - val_accuracy: 0.8687 - val_loss: 0.4057

# %%
# Training Plot
plt.plot(history.history["loss"])
plt.plot(history.history["val_loss"])
plt.plot(history.history["accuracy"])
plt.plot(history.history["val_accuracy"])
plt.legend(["Loss", "Validation Loss", "Accuracy", "Validation Accuracy"])

# %% [markdown]
# Testing

# %%
def test_visualize(images, n = 5):
    """ Visualize a few images """

    def show(ax, image):
        ax.imshow(image)
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)

    fig = plt.figure(figsize=(9, 9))
    axs = fig.subplots(1, n)
    for i in range(n):
        show(axs[i], images[i])

# %% [markdown]
# Test

# %%
test_indices = [0, 1, 2, 3, 4]
test_index = random.sample(range(10), 1)[0]
test_image = face_images[test_index]

compare_images = []
for i in range(5):
    index = random.sample(range(i * 10, (i + 1) * 10), 1)[0]
    image = face_images[index]
    compare_images.append(image)

# %%
plt.imshow(test_image)

# %%
test_visualize(compare_images)

# %%
image_pairs = []

for image in compare_images:
    image_pairs.append((test_image, image))

image_pairs = np.array(image_pairs)

# %%
score = siamese_model.predict([image_pairs[:, 0, :], image_pairs[:, 1, :]])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 513ms/step

# %%
print(score)
# Out:
# [[0.48170418]
#  [0.20907699]
#  [0.07078515]
#  [0.09461936]
#  [0.08992665]]
